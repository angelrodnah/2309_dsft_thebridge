# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadistica
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
df_beer = pd.read_csv("data/datasets_beers.csv") # index_col = 0
# df_beer.set_index("Unnamed: 0", inplace=True)
df_beer.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
df_beer.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
df_beer.shape
# Out:
# (2410, 8)

# %%
df_beer.ndim
# Out:
# 2

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
df_beer.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_beer
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
#       brewery_id  ounces
# ...

# %%
# df_beer.to_csv("data/prueba.csv", index=True)
# df_prueba = pd.read_csv("data/prueba.csv")
# df_prueba

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
print("Filas", df_beer.shape[0])
print("Columnas", df_beer.shape[1])
# Out:
# Filas 2410
# Columnas 7

# %%
df_beer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   abv         2348 non-null   float64
#  1   ibu         1405 non-null   float64
#  2   id          2410 non-null   int64
#  3   name        2410 non-null   object
#  4   style       2405 non-null   object
#  5   brewery_id  2410 non-null   int64
#  6   ounces      2410 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 131.9+ KB

# %%
df_beer.describe()
# Out:
#                abv          ibu           id   brewery_id       ounces
# count  2348.000000  1405.000000  2410.000000  2410.000000  2410.000000
# mean      0.059773    42.713167  1431.113278   231.749793    13.592241
# std       0.013542    25.954066   752.459975   157.685604     2.352204
# min       0.001000     4.000000     1.000000     0.000000     8.400000
# 25%       0.050000    21.000000   808.250000    93.000000    12.000000
# 50%       0.056000    35.000000  1453.500000   205.000000    12.000000
# 75%       0.067000    64.000000  2075.750000   366.000000    16.000000
# max       0.128000   138.000000  2692.000000   557.000000    32.000000

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
df_beer.dtypes.values
# Out:
# array([dtype('float64'), dtype('float64'), dtype('int64'), dtype('O'),
#        dtype('O'), dtype('int64'), dtype('float64')], dtype=object)

# %%
df_beer.dtypes.index
# Out:
# Index(['abv', 'ibu', 'id', 'name', 'style', 'brewery_id', 'ounces'], dtype='object')

# %%
type(df_beer.dtypes)
# Out:
# pandas.core.series.Series

# %%
df_beer.dtypes
# Out:
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %% [markdown]
# ## Ejercicio 6
# Obtén en un nuevo DataFrame un resumen con las principales estadísticas de las columnas numéricas: mean, max, count, cuartiles...

# %%
df_beer[['abv','ibu','ounces']].describe()
# Out:
#                abv          ibu       ounces
# count  2348.000000  1405.000000  2410.000000
# mean      0.059773    42.713167    13.592241
# std       0.013542    25.954066     2.352204
# min       0.001000     4.000000     8.400000
# 25%       0.050000    21.000000    12.000000
# 50%       0.056000    35.000000    12.000000
# 75%       0.067000    64.000000    16.000000
# max       0.128000   138.000000    32.000000

# %%
df_beer[['abv','ibu','ounces']].agg(['mean','count'])
# Out:
#                abv          ibu       ounces
# mean      0.059773    42.713167    13.592241
# count  2348.000000  1405.000000  2410.000000

# %%
df_beer.describe(include="all")
# Out:
#                 abv          ibu           id             name         style  \
# count   2348.000000  1405.000000  2410.000000             2410          2405
# unique          NaN          NaN          NaN             2305            99
# top             NaN          NaN          NaN  Nonstop Hef Hop  American IPA
# freq            NaN          NaN          NaN               12           424
# mean       0.059773    42.713167  1431.113278              NaN           NaN
# std        0.013542    25.954066   752.459975              NaN           NaN
# min        0.001000     4.000000     1.000000              NaN           NaN
# 25%        0.050000    21.000000   808.250000              NaN           NaN
# 50%        0.056000    35.000000  1453.500000              NaN           NaN
# 75%        0.067000    64.000000  2075.750000              NaN           NaN
# max        0.128000   138.000000  2692.000000              NaN           NaN
#
#          brewery_id       ounces
# ...

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
len(df_beer['style'].unique())
# Out:
# 100

# %%
df_beer['style'].nunique()
# Out:
# 99

# %%
df_beer['style'].value_counts()
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# American Malt Liquor                1
# Wheat Ale                           1
# Flanders Red Ale                    1
# Kristalweizen                       1
# Low Alcohol Beer                    1
# Name: style, Length: 99, dtype: int64

# %%
df_beer.groupby("style")['name'].count().sort_values(ascending=False)
# Out:
# style
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Smoked Beer                         1
# Flanders Red Ale                    1
# Kristalweizen                       1
# American Malt Liquor                1
# Flanders Oud Bruin                  1
# Name: name, Length: 99, dtype: int64

# %%
df_beer['style'].value_counts(normalize=True)
# Out:
# American IPA                      0.176299
# American Pale Ale (APA)           0.101871
# American Amber / Red Ale          0.055301
# American Blonde Ale               0.044906
# American Double / Imperial IPA    0.043659
#                                     ...
# American Malt Liquor              0.000416
# Wheat Ale                         0.000416
# Flanders Red Ale                  0.000416
# Kristalweizen                     0.000416
# Low Alcohol Beer                  0.000416
# Name: style, Length: 99, dtype: float64

# %%
df_beer[df_beer['style'].isnull()]
# Out:
#         abv   ibu    id                            name style  brewery_id  \
# 566     NaN   NaN  2210                 Special Release   NaN          29
# 853   0.060  21.0  1635  Kilt Lifter Scottish-Style Ale   NaN         160
# 866   0.053  27.0  2527                   OktoberFiesta   NaN          66
# 1554    NaN   NaN  1796                    The CROWLER™   NaN         166
# 1555    NaN   NaN  1790            CAN'D AID Foundation   NaN         166
#
#       ounces
# 566     16.0
# 853     12.0
# 866     12.0
# 1554    32.0
# 1555    12.0

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros desde el décimo hasta el vigésimo
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
df_beer.iloc[9:20,:]
# Out:
#       abv   ibu    id                         name  \
# 9   0.086   NaN  2131                 Cone Crusher
# 10  0.072   NaN  2099            Sophomoric Saison
# 11  0.073   NaN  2098        Regional Ring Of Fire
# 12  0.069   NaN  2097                   Garce Selé
# 13  0.085   NaN  1980              Troll Destroyer
# 14  0.061  60.0  1979                 Bitter Bitch
# 15  0.060   NaN  2318                  Ginja Ninja
# 16  0.060   NaN  2170                Cherried Away
# 17  0.060   NaN  2169                 Rhubarbarian
# 18  0.060   NaN  1502                  BrightCider
# 19  0.082   NaN  1593  He Said Baltic-Style Porter
#
#                              style  brewery_id  ounces
# 9   American Double / Imperial IPA         177    12.0
# 10          Saison / Farmhouse Ale         177    12.0
# 11          Saison / Farmhouse Ale         177    12.0
# 12          Saison / Farmhouse Ale         177    12.0
# 13                     Belgian IPA         177    12.0
# ...

# %%
df_beer.loc[9:19,"name":"ounces"]
# Out:
#                            name                           style  brewery_id  \
# 9                  Cone Crusher  American Double / Imperial IPA         177
# 10            Sophomoric Saison          Saison / Farmhouse Ale         177
# 11        Regional Ring Of Fire          Saison / Farmhouse Ale         177
# 12                   Garce Selé          Saison / Farmhouse Ale         177
# 13              Troll Destroyer                     Belgian IPA         177
# 14                 Bitter Bitch         American Pale Ale (APA)         177
# 15                  Ginja Ninja                           Cider         154
# 16                Cherried Away                           Cider         154
# 17                 Rhubarbarian                           Cider         154
# 18                  BrightCider                           Cider         154
# 19  He Said Baltic-Style Porter                   Baltic Porter         368
#
#     ounces
# 9     12.0
# 10    12.0
# 11    12.0
# ...

# %%
df_beer[['abv','ibu','ounces']].loc[9:19]
# Out:
#       abv   ibu  ounces
# 9   0.086   NaN    12.0
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0

# %%
df_beer[['abv','ibu','ounces']].loc[9:19].values
# Out:
# array([[ 0.086,    nan, 12.   ],
#        [ 0.072,    nan, 12.   ],
#        [ 0.073,    nan, 12.   ],
#        [ 0.069,    nan, 12.   ],
#        [ 0.085,    nan, 12.   ],
#        [ 0.061, 60.   , 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ]])

# %%
np.array(df_beer[['abv','ibu','ounces']].loc[9:19])
# Out:
# array([[ 0.086,    nan, 12.   ],
#        [ 0.072,    nan, 12.   ],
#        [ 0.073,    nan, 12.   ],
#        [ 0.069,    nan, 12.   ],
#        [ 0.085,    nan, 12.   ],
#        [ 0.061, 60.   , 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ]])

# %%
df_beer[['abv','ibu','ounces']].loc[9:19].to_numpy()
# Out:
# array([[ 0.086,    nan, 12.   ],
#        [ 0.072,    nan, 12.   ],
#        [ 0.073,    nan, 12.   ],
#        [ 0.069,    nan, 12.   ],
#        [ 0.085,    nan, 12.   ],
#        [ 0.061, 60.   , 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ]])

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
df_beer['ounces'].sum()
# Out:
# 32757.3

# %%
df_beer.groupby("style")['ounces'].sum().sort_values(ascending=False)
# Out:
# style
# American IPA                      5758.4
# American Pale Ale (APA)           3233.6
# American Amber / Red Ale          1768.0
# American Double / Imperial IPA    1487.2
# American Blonde Ale               1424.0
#                                    ...
# Low Alcohol Beer                    16.0
# Other                               12.0
# Kristalweizen                       12.0
# Grisette                            12.0
# Braggot                             12.0
# Name: ounces, Length: 99, dtype: float64

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
round(df_beer['ibu'].mean(), 2)
# Out:
# 42.71

# %%
df_beer['ibu'].min()
# Out:
# 4.0

# %%
df_beer['ibu'].max()
# Out:
# 138.0

# %%
df_beer['ibu'].count()/len(df_beer)
# Out:
# 0.58298755186722

# %%
df_beer[df_beer['ibu'] == df_beer['ibu'].min()]
# Out:
#        abv  ibu    id                                  name      style  \
# 106  0.056  4.0  1350                       Summer Solstice  Cream Ale
# 112  0.056  4.0   753  Summer Solstice Cerveza Crema (2009)  Cream Ale
# 117  0.056  4.0    77                Summer Solstice (2011)  Cream Ale
#
#      brewery_id  ounces
# 106         171    12.0
# 112         171    12.0
# 117         171    12.0

# %%
df_beer[df_beer['ibu'] == df_beer['ibu'].max()]
# Out:
#        abv    ibu   id                       name  \
# 147  0.082  138.0  980  Bitter Bitch Imperial IPA
#
#                               style  brewery_id  ounces
# 147  American Double / Imperial IPA         374    12.0

# %%
# df_beer['ibu'].fillna(df_beer['ibu'].mean())

# %%
# df_beer.groupby('style')['ibu'].mean()

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
round(df_beer['ibu'].var(), 2)
# Out:
# 673.61

# %%
round(df_beer['ibu'].std(), 2)
# Out:
# 25.95

# %%
df_beer['ibu'].max() - df_beer['ibu'].min()
# Out:
# 134.0

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonamiento mediante un gráfico

# %%
mat_c = df_beer[['abv','ibu','ounces']].corr()
mat_c
# Out:
#              abv       ibu    ounces
# abv     1.000000  0.670621  0.172529
# ibu     0.670621  1.000000  0.054691
# ounces  0.172529  0.054691  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(mat_c, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
df_beer['abv'].hist(bins=50)
# Out:
# <Axes: >

# %%
from scipy import stats

# %%
stats.skew(df_beer[df_beer['abv'].notnull()]['abv'])
# Out:
# 0.9578647103102429

# %%
df_beer['abv'].skew()
# Out:
# 0.9584771340361382

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
sns.boxplot(x=df_beer['abv'])
# Out:
# <Axes: xlabel='abv'>

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
df_beer.groupby('style')['abv'].mean().sort_values(ascending=False)
# Out:
# style
# English Barleywine        0.107667
# Quadrupel (Quad)          0.104000
# American Barleywine       0.099000
# American Malt Liquor      0.099000
# Russian Imperial Stout    0.097636
#                             ...
# Berliner Weissbier        0.043909
# English Dark Mild Ale     0.041500
# Light Lager               0.040417
# Radler                    0.040333
# Low Alcohol Beer          0.001000
# Name: abv, Length: 99, dtype: float64

# %%
df_beer.groupby('style')['ibu'].mean().sort_values(ascending=False)
# Out:
# style
# American Barleywine                   96.00
# American Double / Imperial IPA        93.32
# Russian Imperial Stout                86.50
# American Double / Imperial Pilsner    85.00
# Belgian Strong Dark Ale               72.00
#                                       ...
# Kristalweizen                           NaN
# Low Alcohol Beer                        NaN
# Mead                                    NaN
# Rauchbier                               NaN
# Shandy                                  NaN
# Name: ibu, Length: 99, dtype: float64

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
df_brew = pd.read_csv('data/datasets_breweries.csv')
df_brew.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
df_brew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558 entries, 0 to 557
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  558 non-null    int64
#  1   name        558 non-null    object
#  2   city        558 non-null    object
#  3   state       558 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 17.6+ KB

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra también la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
df_brew.rename(columns={"Unnamed: 0": "brewery_id", "name":"brewery_name"}, inplace=True)

# %%
df_brew
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
df_brew
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %%
df_beer.shape
# Out:
# (2410, 7)

# %%
df = pd.merge(df_beer, df_brew)
df.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces               brewery_name  city state
# 0         408    12.0  10 Barrel Brewing Company  Bend    OR
# 1         177    12.0        18th Street Brewery  Gary    IN
# 2         177    12.0        18th Street Brewery  Gary    IN
# 3         177    12.0        18th Street Brewery  Gary    IN
# 4         177    12.0        18th Street Brewery  Gary    IN

# %%
df.shape
# Out:
# (2410, 10)

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas cervecerías hay?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2410 entries, 0 to 2409
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   abv           2348 non-null   float64
#  1   ibu           1405 non-null   float64
#  2   id            2410 non-null   int64
#  3   name          2410 non-null   object
#  4   style         2405 non-null   object
#  5   brewery_id    2410 non-null   int64
#  6   ounces        2410 non-null   float64
#  7   brewery_name  2410 non-null   object
#  8   city          2410 non-null   object
#  9   state         2410 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 207.1+ KB

# %%
df['state'].nunique()
# Out:
# 51

# %%
df['city'].nunique()
# Out:
# 384

# %%
len(df['brewery_name'].unique())
# Out:
# 551

# %%
df['brewery_name'].nunique() # No sería correcto, puede haber cervecerías diferentes con el mismo nombre
# Out:
# 551

# %%
df['brewery_id'].nunique()
# Out:
# 558

# %%
df_brew[['brewery_id','brewery_name']].groupby('brewery_name').count().sort_values("brewery_id", ascending=False)
# Out:
#                            brewery_id
# brewery_name
# Blackrocks Brewery                  2
# Sly Fox Brewing Company             2
# Summit Brewing Company              2
# Oskar Blues Brewery                 2
# Otter Creek Brewing                 2
# ...                               ...
# Epic Brewing                        1
# Engine House 9                      1
# Engine 15 Brewing                   1
# Emerald City Beer Company           1
# Wynkoop Brewing Company             1
#
# [551 rows x 1 columns]

# %%
df[df['brewery_name']=="Blackrocks Brewery"]
# Out:
#        abv   ibu    id               name                    style  \
# 286  0.073   NaN  2449      Flying Sailor                 Rye Beer
# 287  0.048  47.0  2634          Nordskye              American IPA
# 288  0.060  30.0  2153  North Third Stout   Foreign / Export Stout
# 289  0.052   NaN  1953          Honey Lav  American Pale Wheat Ale
# 290  0.068   NaN  1496  Coconut Brown Ale       American Brown Ale
# 291  0.070  51.0  1481            51K IPA             American IPA
# 292  0.055   NaN  1480      Grand Rabbits                Cream Ale
#
#      brewery_id  ounces        brewery_name       city state
# 286          95    12.0  Blackrocks Brewery  Marquette    MA
# 287          12    12.0  Blackrocks Brewery  Marquette    MI
# 288          12    12.0  Blackrocks Brewery  Marquette    MI
# 289          12    12.0  Blackrocks Brewery  Marquette    MI
# 290          12    12.0  Blackrocks Brewery  Marquette    MI
# 291          12    12.0  Blackrocks Brewery  Marquette    MI
# ...

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
df.groupby(['state','city'])['abv'].agg(['mean','median','max'])
# Out:
#                       mean  median    max
# state city
#  AK   Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
#  AL   Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
#  WI   Wilson      0.055000  0.0550  0.055
#  WV   Lewisburg   0.062000  0.0620  0.067
#  WY   Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [401 rows x 3 columns]

# %%
# df.groupby(['state','city'], as_index=False)['abv'].agg(['mean','median','max'])['mean'][' AK']['Anchorage']

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
df[df['state']=="IN"]
# Out:
# Empty DataFrame
# Columns: [abv, ibu, id, name, style, brewery_id, ounces, brewery_name, city, state]
# Index: []

# %%
df.head()
# Out:
#      abv  ibu    id                 name                           style  \
# 0  0.050  NaN  1436             Pub Beer             American Pale Lager
# 1  0.066  NaN  2265          Devil's Cup         American Pale Ale (APA)
# 2  0.071  NaN  2264  Rise of the Phoenix                    American IPA
# 3  0.090  NaN  2263             Sinister  American Double / Imperial IPA
# 4  0.075  NaN  2262        Sex and Candy                    American IPA
#
#    brewery_id  ounces               brewery_name  city state
# 0         408    12.0  10 Barrel Brewing Company  Bend    OR
# 1         177    12.0        18th Street Brewery  Gary    IN
# 2         177    12.0        18th Street Brewery  Gary    IN
# 3         177    12.0        18th Street Brewery  Gary    IN
# 4         177    12.0        18th Street Brewery  Gary    IN

# %%
df.loc[1,"state"]
# Out:
# ' IN'

# %%
df[df['state']==" IN"]
# Out:
#         abv   ibu    id                      name  \
# 1     0.066   NaN  2265               Devil's Cup
# 2     0.071   NaN  2264       Rise of the Phoenix
# 3     0.090   NaN  2263                  Sinister
# 4     0.075   NaN  2262             Sex and Candy
# 5     0.077   NaN  2261              Black Exodus
# ...     ...   ...   ...                       ...
# 2195  0.045  35.0   948  Circuit Bohemian Pilsner
# 2275  0.045  50.0  2190      Campside Session IPA
# 2276  0.045  15.0  1951          Upland Wheat Ale
# 2277  0.060   NaN  1950             Dragonfly IPA
# 2329  0.047   NaN   780        T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  \
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# 3     American Double / Imperial IPA         177    12.0
# 4                       American IPA         177    12.0
# 5                      Oatmeal Stout         177    12.0
# ...

# %%
df[df['state'].str.contains("IN")]
# Out:
#         abv   ibu    id                      name  \
# 1     0.066   NaN  2265               Devil's Cup
# 2     0.071   NaN  2264       Rise of the Phoenix
# 3     0.090   NaN  2263                  Sinister
# 4     0.075   NaN  2262             Sex and Candy
# 5     0.077   NaN  2261              Black Exodus
# ...     ...   ...   ...                       ...
# 2195  0.045  35.0   948  Circuit Bohemian Pilsner
# 2275  0.045  50.0  2190      Campside Session IPA
# 2276  0.045  15.0  1951          Upland Wheat Ale
# 2277  0.060   NaN  1950             Dragonfly IPA
# 2329  0.047   NaN   780        T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  \
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# 3     American Double / Imperial IPA         177    12.0
# 4                       American IPA         177    12.0
# 5                      Oatmeal Stout         177    12.0
# ...

# %%
df[df['state'].str.strip()=="IN"]
# Out:
#         abv   ibu    id                      name  \
# 1     0.066   NaN  2265               Devil's Cup
# 2     0.071   NaN  2264       Rise of the Phoenix
# 3     0.090   NaN  2263                  Sinister
# 4     0.075   NaN  2262             Sex and Candy
# 5     0.077   NaN  2261              Black Exodus
# ...     ...   ...   ...                       ...
# 2195  0.045  35.0   948  Circuit Bohemian Pilsner
# 2275  0.045  50.0  2190      Campside Session IPA
# 2276  0.045  15.0  1951          Upland Wheat Ale
# 2277  0.060   NaN  1950             Dragonfly IPA
# 2329  0.047   NaN   780        T-6 Red Ale (2004)
#
#                                style  brewery_id  ounces  \
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# 3     American Double / Imperial IPA         177    12.0
# 4                       American IPA         177    12.0
# 5                      Oatmeal Stout         177    12.0
# ...

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
df['ibu'].describe()
# Out:
# count    1405.000000
# mean       42.713167
# std        25.954066
# min         4.000000
# 25%        21.000000
# 50%        35.000000
# 75%        64.000000
# max       138.000000
# Name: ibu, dtype: float64

# %%
df[df['ibu'].notnull()].groupby('city')['ibu'].describe().sort_values("count", ascending=False)
# Out:
#                count        mean        std    min     25%    50%    75%  \
# city
# Portland        41.0   41.170732  24.976892   13.0   20.00   30.0   61.0
# Indianapolis    36.0   45.472222  25.020547   20.0   23.00   30.0   75.0
# San Diego       35.0   54.200000  28.402361   15.0   29.00   44.0   75.0
# Brooklyn        28.0   51.071429  25.019886    7.0   34.75   49.0   62.5
# Boulder         26.0   37.500000  20.717625   10.0   20.50   32.0   49.5
# ...              ...         ...        ...    ...     ...    ...    ...
# Phoenixville     1.0   70.000000        NaN   70.0   70.00   70.0   70.0
# Bridgman         1.0   35.000000        NaN   35.0   35.00   35.0   35.0
# St Paul          1.0   49.000000        NaN   49.0   49.00   49.0   49.0
# St Petersburg    1.0   82.000000        NaN   82.0   82.00   82.0   82.0
# Abingdon         1.0  135.000000        NaN  135.0  135.00  135.0  135.0
#
#                  max
# city
# Portland       103.0
# Indianapolis   104.0
# ...

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame de todas las cervezas en cuyas cervecerías al menos haya una cerveza con un `abv` mínimo 0.07.

# %%
ejer_23 = df[df['abv']>=0.07]['brewery_id'].unique()
ejer_23
# Out:
# array([177, 368,  67,  27, 481,  62,   1, 117, 171, 193,  69, 426, 429,
#        353, 523, 374,  72, 413,  37, 360, 235,  34,  20, 292, 306,  76,
#         53,  75, 463, 220, 477,   8,  40, 336, 444,  18, 112, 294,  95,
#         12, 380, 304, 489, 107, 231, 219, 308,  10, 530, 214,  24,   5,
#        230, 222, 331, 285,  29, 350, 236, 226,  99, 141, 515,  63, 315,
#        227, 358, 127, 263,  57, 491, 369, 465,  26, 173, 224, 405, 201,
#        172, 256,  48, 521,  50, 279, 206,  15, 287, 105, 460, 433, 180,
#        228, 240,  39, 464, 478, 165,   6, 365,  86, 124, 327, 248, 343,
#        204, 280, 479, 423, 168, 198, 395,  80, 242,   2,  92, 233, 208,
#        125, 354, 332, 149, 268,  91, 356, 346, 317, 161, 375, 203, 393,
#          3,  65, 284, 134,  98, 209, 514, 188, 260, 507, 143, 387, 410,
#        174, 495, 359, 184, 148, 471, 301, 166, 503, 389, 355, 314, 274,
#        128, 475,  68, 421, 110,  93,  43, 229, 376, 164, 397,  30, 252,
# ...

# %%
df[df['brewery_id'].isin(ejer_23)]
# Out:
#         abv   ibu    id                  name                           style  \
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# 5     0.077   NaN  2261          Black Exodus                   Oatmeal Stout
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %%
ejer_23 = df.groupby('brewery_id')['abv'].max()
brew_23 = ejer_23[ejer_23 >= 0.07]
brew_23
# Out:
# brewery_id
# 1      0.125
# 2      0.072
# 3      0.080
# 5      0.097
# 6      0.095
#        ...
# 522    0.085
# 523    0.070
# 524    0.080
# 530    0.099
# 550    0.072
# Name: abv, Length: 227, dtype: float64

# %%
df[df['brewery_id'].isin(brew_23.index)]
# Out:
#         abv   ibu    id                  name                           style  \
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# 5     0.077   NaN  2261          Black Exodus                   Oatmeal Stout
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
df['ibu'].mean()
# Out:
# 42.71316725978647

# %%
serie_24 = df.groupby('state')['ibu'].mean()
filtered_states = serie_24[serie_24 > df['ibu'].mean()]

# %%
filtered_states.index
# Out:
# Index([' AL', ' CA', ' CO', ' DC', ' DE', ' FL', ' GA', ' ID', ' IN', ' ME',
#        ' MN', ' MS', ' NC', ' NH', ' NJ', ' NM', ' NV', ' NY', ' OH', ' OR',
#        ' UT', ' VA', ' WA', ' WV'],
#       dtype='object', name='state')

# %%
df[df['state'].isin(filtered_states.index)]
# Out:
#         abv   ibu    id                  name                           style  \
# 0     0.050   NaN  1436              Pub Beer             American Pale Lager
# 1     0.066   NaN  2265           Devil's Cup         American Pale Ale (APA)
# 2     0.071   NaN  2264   Rise of the Phoenix                    American IPA
# 3     0.090   NaN  2263              Sinister  American Double / Imperial IPA
# 4     0.075   NaN  2262         Sex and Candy                    American IPA
# ...     ...   ...   ...                   ...                             ...
# 2405  0.067  45.0   928             Belgorado                     Belgian IPA
# 2406  0.052   NaN   807         Rail Yard Ale        American Amber / Red Ale
# 2407  0.055   NaN   620       B3K Black Lager                     Schwarzbier
# 2408  0.055  40.0   145   Silverback Pale Ale         American Pale Ale (APA)
# 2409  0.052   NaN    84  Rail Yard Ale (2009)        American Amber / Red Ale
#
# ...
